# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.hist(bins=50, grid = True, figsize=(15,15));

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
questions = ["1. How many people have heart disease problem and how many people doesn't have heart problems?",
"2. People of which sex has most heart problem?",
"4. People with which chestpain are most pron to have heart diseases?",
"5. Which age people are most in the dataset ?",
"3. People of which sex has which types of chest pain most?",
"6. People of which sex has fasting blood sugar?",
"7. People of which see has most resting electrocardiographic results?"]

questions
#Question-1
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
df.target.value_counts().plot(kind = "bar", color = ["orchid", "salmon"])
plt.title("Heart Disease values")
plt.xlabel("1 Heart Disease, No Heart Disease")
plt.ylabel("Amount");

# %%
df.target.value_counts().plot(kind = 'pie', figsize= (5,5)) 
plt.legend(["Disease","No Disease"]);

# %%
df.sex.value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
df.sex.value_counts().plot(kind = 'pie', figsize = (5,5))
plt.title("Male-Female Ratio")
plt.legend(["Male","Female"]);

# %%
#2. People of which sex has most heart disease?
pd.crosstab(df.target,df.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
sns.countplot(x='target', data=df, hue="sex") 
plt.title("heart disease frequency for sex") 
plt.xlabel("a= No Heart disease, I Heart disease");
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.countplot(x='target', data=df, hue="sex")
#       2 plt.title("heart disease frequency for sex")
#       3 plt.xlabel("a= No Heart disease, I Heart disease")
#
# File ~\Anaconda\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\Anaconda\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
#3. People of which sex has which types of chest pain most? 
df.cp.value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
pd.crosstab(df.sex, df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(df.sex,df.cp).plot(kind = "bar",color = ['red', 'blue','green','yellow'])
plt.title('Type of chest pain for sex')
plt.xlabel('0=Female, 1=Male')
# Out:
# Text(0.5, 0, '0=Female,\xa01=Male')

# %%
#Question 4
pd.crosstab(df.cp,df.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
sns.countplot(x='cp',data = df, hue = 'target');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.countplot(x='cp',data = df, hue = 'target')
#
# File ~\Anaconda\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\Anaconda\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\Anaconda\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
#Question-5
sns.displot(x='age', data=df, bins=30, kde=True);
# Out:
# C:\Users\Kavan\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Question-6
df.fbs.value_counts()
# Out:
# fbs
# 0    872
# 1    153
# Name: count, dtype: int64

# %%
df.fbs.value_counts().plot(kind='bar' ,color = ['green', 'blue'])
plt.title('fasting blood sugar vs count');

# %%
pd.crosstab(df.sex, df.fbs)
# Out:
# fbs    0    1
# sex
# 0    270   42
# 1    602  111

# %%
pd.crosstab(df.sex,df.fbs).plot(kind='bar',color=['coral', 'springgreen']) 
plt.title('fasting blood sugar for sex')
plt.xlabel("0=Female, 1=Male");

# %%
#Question-7
df.restecg.value_counts()
# Out:
# restecg
# 1    513
# 0    497
# 2     15
# Name: count, dtype: int64

# %%
pd.crosstab(df.sex,df.restecg)
# Out:
# restecg    0    1   2
# sex
# 0        144  157  11
# 1        353  356   4

# %%
pd.crosstab(df.sex,df.restecg).plot(kind='bar',color=['coral', 'pink', 'orange']) 
plt.title('retsing electrocardiogarphic results for sex')
plt.xlabel('0=female,1=male');
